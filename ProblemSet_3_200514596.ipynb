# %% [markdown]
# # Question 1

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\jayma\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jayma\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\jayma\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# Step 2 and 3. Import the dataset and assign it to a variable called users

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|')
users.head(10)
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %% [markdown]
# Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
male_ratio = users.groupby('occupation')['gender'].apply(lambda x: (x == 'M').mean())
male_ratio_sorted = male_ratio.sort_values(ascending=False)
male_ratio_sorted
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: gender, dtype: float64

# %% [markdown]
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
age_min_max = users.groupby('occupation')['age'].agg(['min', 'max'])
age_min_max
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# Step 7. For each combination of occupation and sex, calculate the mean age

# %%
mean_age_by_occupation_sex = users.groupby(['occupation', 'gender'])['age'].mean()
mean_age_by_occupation_sex
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# Step 8. For each occupation present the percentage of women and men

# %%
gender_percentage_by_occupation = users.groupby(['occupation', 'gender']).size() / users.groupby('occupation').size() * 100
gender_percentage_by_occupation
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# # Question 2

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2 and 3. Import the dataset and assign it to a variable called euro12

# %%
euro = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 4. Select only the Goal column

# %%
euro['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step 5. How many team participated in the Euro2012?

# %%
print("Number of teams participated in the Euro 2012: ",euro['Team'].nunique())
# Out:
# Number of teams participated in the Euro 2012:  16

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
print("No. of columns:" ,euro.shape[1])
# Out:
# No. of columns: 35

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
sorted_df = euro.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=False)
sorted_df[['Team', 'Red Cards', 'Yellow Cards']]
# Out:
#                    Team  Red Cards  Yellow Cards
# 6                Greece          1             9
# 9                Poland          1             7
# 11  Republic of Ireland          1             6
# 7                 Italy          0            16
# 10             Portugal          0            12
# 13                Spain          0            11
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 14               Sweden          0             7
# 4                France          0             6
# 12               Russia          0             6
# 3               England          0             5
# 8           Netherlands          0             5
# 15              Ukraine          0             5
# 2               Denmark          0             4
# 5               Germany          0             4

# %% [markdown]
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
mean_yellow_cards = euro.groupby('Team')['Yellow Cards'].mean()
mean_yellow_cards
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %% [markdown]
# Step 10. Filter teams that scored more than 6 goals

# %%
high_scoring_teams = euro[euro['Goals'] > 6]
high_scoring_teams[['Team','Goals']]
# Out:
#        Team  Goals
# 5   Germany     10
# 13    Spain     12

# %% [markdown]
# Step 11. Select the teams that start
# with G

# %%
teams_starting_with_G = euro[euro['Team'].str.startswith('G')]
print(teams_starting_with_G[['Team']])
# Out:
#       Team
# 5  Germany
# 6   Greece

# %% [markdown]
# Step 12. Select the first 7 columns

# %%
euro.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %% [markdown]
# Step 13. Select all columns except the last 3

# %%
euro.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
selected_teams_shooting_accuracy = euro.loc[euro['Team'].isin(['England', 'Italy', 'Russia']), 'Shooting Accuracy']
selected_teams_shooting_accuracy
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# # Question 3

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2. Create 3 differents Series, each of length 100, as follows:

# %% [markdown]
# 1. The first a random number from 1 to 4

# %% [markdown]
# 2. The second a random number from 1 to 3

# %% [markdown]
# 3. The third a random number from 10,000 to 30,000

# %%
series1 = pd.Series(np.random.randint(1, 5, size=100), name='Series1')
series2 = pd.Series(np.random.randint(1, 4, size=100), name='Series2')
series3 = pd.Series(np.random.randint(10000, 30001, size=100), name='Series3')

# %% [markdown]
# Step 3. Create a DataFrame by joinning the Series by column

# %%
housing_df = pd.concat([series1, series2, series3], axis=1)
housing_df
# Out:
#     Series1  Series2  Series3
# 0         2        1    15168
# 1         2        2    16019
# 2         3        1    15282
# 3         4        3    14145
# 4         4        3    28864
# ..      ...      ...      ...
# 95        1        3    25287
# 96        3        3    20203
# 97        3        2    11959
# 98        1        1    18325
# 99        4        2    20742
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
housing_df.rename(columns = {'Series1': 'bedrs', 'Series2': 'bathrs', 'Series3': 'price_sqr_meter'}, inplace=True)
housing_df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      2       1            15168
# 1      2       2            16019
# 2      3       1            15282
# 3      4       3            14145
# 4      4       3            28864

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.DataFrame({'bigcolumn': pd.concat([series1, series2, series3], axis=0, ignore_index=True)})
bigcolumn
# Out:
#      bigcolumn
# 0            2
# 1            2
# 2            3
# 3            4
# 4            4
# ..         ...
# 295      25287
# 296      20203
# 297      11959
# 298      18325
# 299      20742
#
# [300 rows x 1 columns]

# %% [markdown]
# Step 6. Ops it seems it is going only until index 99. Is it true?

# %%
if bigcolumn.index.max() == 99:
    print("Yes, the index goes up to 99")
else:
    print("No, the index is not going only up to 99")
# Out:
# No, the index is not going only up to 99

# %% [markdown]
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn
# Out:
#      bigcolumn
# 0            2
# 1            2
# 2            3
# 3            4
# 4            4
# ..         ...
# 295      25287
# 296      20203
# 297      11959
# 298      18325
# 299      20742
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question 4

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime

# %% [markdown]
# Step 2 and 3. Import the dataset from the attached file wind.txt and assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('wind.txt', sep = "\s+", parse_dates = [[0,1,2]]) 
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(lambda x: pd.to_datetime(x).replace(year=x.year - 100) if x.year > 1989 else x)
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data['Yr_Mo_Dy'] = pd.to_datetime(data['Yr_Mo_Dy'])
data.set_index('Yr_Mo_Dy', inplace=True)
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below

# %%
missing_values_per_location = data.isna().sum()
print(missing_values_per_location)
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %%
non_missing_values_count = data.notnull().sum().sum()
non_missing_values_count
# Out:
# 78857

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

# %%
mean_windspeed = data.mean().mean()
mean_windspeed
# Out:
# 10.227982360836924

# %% [markdown]
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days

# %%
location_stats = data.describe().transpose()[['min', 'max', 'mean', 'std']]
location_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day

# %%
day_stats = data.transpose().describe().transpose()[['min', 'max', 'mean', 'std']]
day_stats
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# Step 11. Find the average windspeed in January for each location.

# %%
january_data = data[data.index.month == 1]
average_windspeed_january = january_data.mean()

print("Average windspeed in January for each location:")
print(average_windspeed_january)
# Out:
# Average windspeed in January for each location:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# Step 12. Downsample the record to a yearly frequency for each location.

# %%
yearly_resampled = data.resample('Y').mean()
yearly_resampled
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# Step 13. Downsample the record to a monthly frequency for each location.

# %%
monthly_resampled = data.resample('M').mean()
monthly_resampled
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# Step 14. Downsample the record to a weekly frequency for each location

# %%
weekly_resampled = data.resample('W').mean()
weekly_resampled
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
weekly_resampled = data.loc['1961-01-02':].resample('W').agg(['min', 'max', 'mean', 'std'])
weekly_resampled_first_52 = weekly_resampled.head(52)
weekly_resampled_first_52
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
# 1961-03-19   4.92  16.88  11.911429  3.860036   9.46  15.54  13.501429
# ...

# %% [markdown]
# # Question 5:

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Step 2 and 3. Import the dataset from this address and assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# Step 5. What is the number of observations in the dataset?

# %%
num_observations = chipo.shape[0]
print("Number of observations in the dataset:", num_observations)
# Out:
# Number of observations in the dataset: 4622

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
num_columns = chipo.shape[1]
print("Number of columns in the dataset:", num_columns)
# Out:
# Number of columns in the dataset: 5

# %% [markdown]
# Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9. Which was the most-ordered item?

# %%
most_ordered_item = chipo.groupby('item_name')['quantity'].sum().idxmax()

print("The most-ordered item:", most_ordered_item)
# Out:
# The most-ordered item: Chicken Bowl

# %% [markdown]
# Step 10. For the most-ordered item, how many items were ordered?

# %%
print('For the most-ordered item, ordered were:', chipo.groupby('item_name')['quantity'].sum().nlargest(1).values[0])
# Out:
# For the most-ordered item, ordered were: 761

# %% [markdown]
# Step 11. What was the most ordered item in the choice_description column?

# %%
most_ordered_choice = chipo.groupby('choice_description')['quantity'].sum().idxmax()
print("The most-ordered item in choice_description:", most_ordered_choice)
# Out:
# The most-ordered item in choice_description: [Diet Coke]

# %% [markdown]
# Step 12. How many items were ordered in total?

# %%
total_items_ordered = chipo['quantity'].sum()
print("Total number of items ordered:", total_items_ordered)
# Out:
# Total number of items ordered: 4972

# %% [markdown]
# Step 13.

# %% [markdown]
# 1. Turn the item price into a float

# %% [markdown]
# 2. Check the item price type

# %% [markdown]
# 3. Create a lambda function and change the type of item price

# %% [markdown]
# 4. Check the item price type

# %%
try:
    item_price_float = lambda x: float(x[1:-1])
    chipo.item_price = chipo.item_price.apply(item_price_float)
except:TypeError

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# Step 14. How much was the revenue for the period in the dataset?

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']
total_revenue = chipo['revenue'].sum()
print("Total revenue for the period: $", total_revenue)
# Out:
# Total revenue for the period: $ 39237.02

# %% [markdown]
# Step 15. How many orders were made in the period?

# %%
total_orders = chipo['order_id'].nunique()
print("Total number of orders made in the period:", total_orders)
# Out:
# Total number of orders made in the period: 1834

# %% [markdown]
# Step 16. What is the average revenue amount per order?

# %%
average_revenue_per_order = total_revenue / total_orders
print("Average revenue amount per order:", average_revenue_per_order)
# Out:
# Average revenue amount per order: 21.39423118865867

# %% [markdown]
# Step 17. How many different items are sold?

# %%
num_different_items_sold = chipo['item_name'].nunique()
print("Number of different items sold:", num_different_items_sold)
# Out:
# Number of different items sold: 50

# %% [markdown]
# # Question 6:

# %% [markdown]
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend. Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
us_marriage_divorce_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
us_marriage_divorce_data.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
plt.figure(figsize=(10, 6))

plt.plot(us_marriage_divorce_data['Year'], us_marriage_divorce_data['Marriages_per_1000'], label='Marriages per 1000', color='green')

plt.plot(us_marriage_divorce_data['Year'], us_marriage_divorce_data['Divorces_per_1000'], label='Divorces per 1000', color='red')

plt.xlabel('Year')
plt.ylabel('Per Capita Rates')
plt.title('Number of Marriages and Divorces per Capita in the U.S. (1867-2014)')
plt.legend()
plt.show()

# %% [markdown]
# # Question 7:

# %% [markdown]
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.

# %%
us_marriage_divorce_data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
us_marriage_divorce_data.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
selected_years = [1900, 1950, 2000]
selected_data = us_marriage_divorce_data[us_marriage_divorce_data['Year'].isin(selected_years)]

plt.figure(figsize=(10, 6))
plt.bar(selected_data['Year'] - 0.2, selected_data['Marriages_per_1000'], width=0.4, label='Marriages per 1000', color='green')
plt.bar(selected_data['Year'] + 0.2, selected_data['Divorces_per_1000'], width=0.4, label='Divorces per 1000', color='red')

plt.xlabel('Year')
plt.ylabel('Per Capita Rates')
plt.title('Number of Marriages and Divorces per Capita in the U.S. (1900, 1950, 2000)')
plt.legend()
plt.show()

# %% [markdown]
# # Question 8:

# %% [markdown]
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.

# %%
hollywood_actor_kills_data = pd.read_csv('actor_kill_counts.csv')
hollywood_actor_kills_data.head()
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239

# %%
hollywood_actor_kills_data = hollywood_actor_kills_data.sort_values(by='Count', ascending=True)


plt.figure(figsize=(10, 6))

plt.barh(hollywood_actor_kills_data['Actor'], hollywood_actor_kills_data['Count'], color='skyblue')
plt.xlabel('Kill Count')
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood')

for index, value in enumerate(hollywood_actor_kills_data['Count']):
    plt.text(value, index, str(value))

plt.show()

# %% [markdown]
# # Question 9:

# %% [markdown]
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated. Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
roman_emperors_data = pd.read_csv('roman-emperor-reigns.csv')
roman_emperors_data.head(3)
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated

# %%
assassinated_count = roman_emperors_data[roman_emperors_data['Cause_of_Death'].str.contains('assassinated', case=False)].shape[0]

not_assassinated_count = roman_emperors_data.shape[0] - assassinated_count
plt.figure(figsize=(8, 8))

labels = ['Assassinated', 'Not Assassinated']
sizes = [assassinated_count, not_assassinated_count]
colors = ['#ff9999', '#66b3ff']
explode = (0.1, 0)  # explode 1st slice

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, explode=explode)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')  
plt.title('Fraction of Roman Emperors Assassinated')

plt.show()

# %% [markdown]
# # Question 10:

# %% [markdown]
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.

# %%
import matplotlib.cm as cm

# %%
arcade_revenue_vs_cs_doctorates_data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

# %%
plt.figure(figsize=(10, 6))

plt.scatter(arcade_revenue_vs_cs_doctorates_data['Total Arcade Revenue (billions)'], arcade_revenue_vs_cs_doctorates_data['Computer Science Doctorates Awarded (US)'], color='blue', alpha=0.7)

plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')
plt.title('Relationship Between Arcade Revenue and Computer Science Doctorates (2000-2009)')

plt.show()
